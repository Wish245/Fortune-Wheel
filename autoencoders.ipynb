# %% [markdown]
# <a href="https://colab.research.google.com/github/Wish245/Fortune-Wheel/blob/main/autoencoders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models

# Load and preprocess dataset
(X_train, _), (X_test, _) = mnist.load_data()

# Normalize images to [-1, 1] and flatten to (784,)
X_train = (X_train.astype(np.float32) - 127.5) / 127.5
X_train = X_train.reshape(-1, 784)

X_test = (X_test.astype(np.float32) - 127.5) / 127.5
X_test = X_test.reshape(-1, 784)

# Check the shapes
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")

# Define the encoder
def build_encoder():
    input_img = layers.Input(shape=(784,))
    encoded = layers.Dense(128, activation='relu')(input_img)
    encoded = layers.Dense(64, activation='relu')(encoded)
    return models.Model(input_img, encoded)

# Define the decoder
def build_decoder():
    encoded_input = layers.Input(shape=(64,))
    decoded = layers.Dense(128, activation='relu')(encoded_input)
    decoded = layers.Dense(784, activation='sigmoid')(decoded)
    return models.Model(encoded_input, decoded)

# Build the full autoencoder
encoder = build_encoder()
decoder = build_decoder()

input_img = layers.Input(shape=(784,))
encoded_img = encoder(input_img)
decoded_img = decoder(encoded_img)

autoencoder = models.Model(input_img, decoded_img)
# Out:
# X_train shape: (60000, 784)
# X_test shape: (10000, 784)

# %%
# Compile and train the autoencoder
autoencoder.compile(optimizer='adam', loss='mse')

# Train the autoencoder
autoencoder.fit(X_train, X_train, epochs=50, batch_size=256, validation_data=(X_test, X_test))
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 1.0587 - val_loss: 0.9258
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.9255 - val_loss: 0.9258
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.9255 - val_loss: 0.9258
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.9251 - val_loss: 0.9258
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.9252 - val_loss: 0.9258
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9252 - val_loss: 0.9258
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.9255 - val_loss: 0.9258
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.9255 - val_loss: 0.9258
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9252 - val_loss: 0.9258
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.9253 - val_loss: 0.9258
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.9254 - val_loss: 0.9258
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9255 - val_loss: 0.9258
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9254 - val_loss: 0.9258
